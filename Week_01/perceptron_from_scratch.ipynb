# %% [markdown]
# <a href="https://colab.research.google.com/github/Umair505/deep-learning-journey/blob/main/Week_01/perceptron_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
w = np.array([2,2])
x = np.array([2,2])
dot = np.dot(w,x)
dot
# Out:
# np.int64(8)
